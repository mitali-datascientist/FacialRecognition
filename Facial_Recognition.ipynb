# %% [markdown]
# <a href="https://colab.research.google.com/github/mitali-datascientist/FacialRecognition/blob/master/Facial_Recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## Import OpenCV library
import cv2

# %%
# Create the haar cascade
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
# Read the image
image = cv2.imread("/content/image2.png")

# %%
## Convert image to gray (This is done so that less information is stored in the pixels)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
gray
# Out:
# array([[ 77,  66,  63, ...,  36,  18,  18],
#        [ 82,  71,  63, ...,  36,  18,  18],
#        [ 84,  71,  60, ...,  36,  17,  25],
#        ...,
#        [ 45,  22,  19, ..., 225, 110,   3],
#        [ 47,  60,  62, ..., 232, 157,   3],
#        [ 58,  53,  68, ..., 229, 150,   4]], dtype=uint8)

# %%
#Try to detect faces
faces = faceCascade.detectMultiScale(
   gray,
   scaleFactor=1.1,
   minNeighbors=5,
   minSize=(20, 30),
   flags = cv2.CASCADE_SCALE_IMAGE 
)

print("Found {0} faces!".format(len(faces)))
# Out:
# Found 4 faces!

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.imshow(image)
plt.show()
